# %%
import csv
import requests
import pandas as pd

prefix='臺中市西區'

url = "https://data.nhi.gov.tw/resource/mask/maskdata.csv"

prefix_list = []
row_count = 0

with requests.Session() as s:
    download = s.get(url)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    original_list = list(cr)

    #print('original_list len = %d' % (len(original_list)-1))


    for row in original_list:
        row_count = row_count+1
        if row_count != 1:
            if prefix == '':
                prefix_list.append(row)
            elif row[2].startswith(prefix):
                prefix_list.append(row)
    #print('prefix_list len= %d' % len(prefix_list))

def myFunc(row):
    return int(row[4])

prefix_list.sort(key=myFunc, reverse=True)

prefix_list.insert(0, original_list[0])

mask_df = pd.DataFrame(prefix_list)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(mask_df)
# Out:
#              0         1                     2             3        4  \
# 0      ﻿醫事機構代碼    醫事機構名稱                醫事機構地址        醫事機構電話  成人口罩剩餘數
# 1   5903240367      宇祥藥局       臺中市西區五權五街１１９號１樓  (04)23728239     1100
# 2   5917030726      元泉藥局       臺中市西區公益里中美街２５７號  (04)23015503      970
# 3   5917032891    中山福倫藥局      臺中市西區中山路４８３號１、２樓  (04)22026818      630
# 4   5917032640     幸福大藥局      臺中市西區向上路一段１９４號１樓  (04)23026149      600
# 5   5917030646      華隆藥局          臺中市西區樂群街６之２號  (04)22243785      550
# 6   5917030100      裕源藥局  臺中市西區公館里南屯路一段６６－７號一樓  (04)23763133      520
# 7   5917032800       壹藥局      臺中市西區美村路１段７７５號１樓  (04)23721998      390
# 8   5903240205      捷登藥局          臺中市西區公益路１０６號  (04)23191929      120
# 9   5903240278      美術藥局        臺中市西區美村路一段５６７號  (04)23725286       30
# 10  5903240143      利民藥局         臺中市西區四維街２３號１樓  (04)22292931        0
# 11  5903240170    美村全成藥局      臺中市西區美村路１段２２２號１樓  (04)23014006        0
# 12  5903240385      喆星藥局          臺中市西區精誠路４２２號  (04)24715301        0
# 13  5903240429      神農藥局      臺中市西區公益路１９０之１號１樓  (04)23103335        0
# 14  5917030226  九和大藥局向上店      臺中市西區向上路一段１９２號１樓  (04)23020148        0
# 15  5917030271      國良藥局        臺中市西區西屯路１段２２０號  (04)22018772        0
# 16  5917030520      林西藥局    臺中市西區永龍里向上路一段４６－１號  (04)23014023        0
# 17  5917030600      永昇藥局        臺中市西區東昇里朝陽街４５號  (04)23717280        0
# 18  5917030860      振聲藥局   臺中市西區公正里向上路１段４４７號１樓  (04)24721100        0
# 19  5917030995   麗新健保大藥局        臺中市西區向上路一段１６２號  (04)23017100        0
# 20  5917032613     向日睽藥局       臺中市西區林森路９８－２號１樓  (04)23731893        0
#
#           5                    6
# 0   兒童口罩剩餘數               來源資料時間
# 1      1690  2022/05/02 13:47:23
# 2       830  2022/05/02 13:47:23
# 3      1240  2022/05/02 13:47:23
# 4       340  2022/05/02 13:47:23
# 5      1150  2022/05/02 13:47:23
# 6      1600  2022/05/02 13:47:23
# 7       240  2022/05/02 13:47:23
# 8       820  2022/05/02 13:47:23
# 9      1080  2022/05/02 13:47:23
# 10     1810  2022/05/02 13:47:23
# 11      980  2022/05/02 13:47:23
# 12      360  2022/05/02 13:47:23
# 13      550  2022/05/02 13:47:23
# 14     1020  2022/05/02 13:47:23
# 15      380  2022/05/02 13:47:23
# 16     1250  2022/05/02 13:47:23
# 17     1010  2022/05/02 13:47:23
# 18      180  2022/05/02 13:47:23
# 19      310  2022/05/02 13:47:23
# 20      890  2022/05/02 13:47:23

# %%
import pandas as pd

header_data = ['即時口罩查詢', '', '','','','','']
author_data = ['劉祐安 ADT110134', '', '','','','','']
prefix_list.insert(0, header_data)
prefix_list.insert(0, author_data)

mask_df = pd.DataFrame(prefix_list)

data = mask_df
df = pd.DataFrame(data)

excel_file = 'mask_df.xlsx'

df.to_excel(excel_file, index=False)
